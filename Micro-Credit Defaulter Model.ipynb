# %% [raw]
# Micro-Credit Defaulter Model
# Problem Statement:
# A Microfinance Institution (MFI) is an organization that offers financial services to low income populations. MFS becomes very useful when targeting especially the unbanked poor families living in remote areas with not much sources of income. The Microfinance services (MFS) provided by MFI are Group Loans, Agricultural Loans, Individual Business Loans and so on.
# Many microfinance institutions (MFI), experts and donors are supporting the idea of using mobile financial services (MFS) which they feel are more convenient and efficient, and cost saving, than the traditional high-touch model used since long for the purpose of delivering microfinance services. Though, the MFI industry is primarily focusing on low income families and are very useful in such areas, the implementation of MFS has been uneven with both significant challenges and successes.
# Today, microfinance is widely accepted as a poverty-reduction tool, representing $70 billion in outstanding loans and a global outreach of 200 million clients.
# We are working with one such client that is in Telecom Industry. They are a fixed wireless telecommunications network provider. They have launched various products and have developed its business and organization based on the budget operator model, offering better products at Lower Prices to all value conscious customers through a strategy of disruptive innovation that focuses on the subscriber.
# They understand the importance of communication and how it affects a person’s life, thus, focusing on providing their services and products to low income families and poor customers that can help them in the need of hour.
# They are collaborating with an MFI to provide micro-credit on mobile balances to be paid back in 5 days. The Consumer is believed to be defaulter if he deviates from the path of paying back the loaned amount within the time duration of 5 days. For the loan amount of 5 (in Indonesian Rupiah), payback amount should be 6 (in Indonesian Rupiah), while, for the loan amount of 10 (in Indonesian Rupiah), the payback amount should be 12 (in Indonesian Rupiah).
# The sample data is provided to us from our client database. It is hereby given to you for this exercise. In order to improve the selection of customers for the credit, the client wants some predictions that could help them in further investment and improvement in selection of customers.
# Exercise:
# Build a model which can be used to predict in terms of a probability for each loan transaction, whether the customer will be paying back the loaned amount within 5 days of insurance of loan. In this case, Label ‘1’ indicates that the loan has been payed i.e. Non- defaulter, while, Label ‘0’ indicates that the loan has not been payed i.e. defaulter.
# Points to Remember:
# •	There are no null values in the dataset.
# •	There may be some customers with no loan history.
# •	The dataset is imbalanced. Label ‘1’ has approximately 87.5% records, while, label ‘0’ has approximately 12.5% records.
# •	For some features, there may be values which might not be realistic. You may have to observe them and treat them with a suitable explanation.
# •	You might come across outliers in some features which you need to handle as per your understanding. Keep in mind that data is expensive and we cannot lose more than 7-8% of the data.

# %%
#Importing libraries
import pandas as pd
import numpy as np

# Importing Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing dataset
df=pd.read_csv("E:\\fliprobo assignments\\micro credit project\\Micro Credit Project\\Data file.csv")
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
df.shape
# Out:
# (209593, 37)

# %% [markdown]
# The dataset contains 209593 rows and 37 columns.

# %%
#Checking null values
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# There is no null values present in dataset.

# %%
#Checking datatypes
df.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# ...

# %% [markdown]
# The dataset contains int, float and object datatypes.

# %% [markdown]
# # Encoding DataFrame

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtype=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#         Unnamed: 0  label  msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0   40191   272.0   3055.050000   3065.150000
# 1                2      1  142291   712.0  12122.000000  12124.750000
# 2                3      1   33594   535.0   1398.000000   1398.000000
# 3                4      1  104157   241.0     21.228000     21.228000
# 4                5      1    6910   947.0    150.619333    150.619333
# ...            ...    ...     ...     ...           ...           ...
# 209588      209589      1   42866   404.0    151.872333    151.872333
# 209589      209590      1  178248  1075.0     36.936000     36.936000
# 209590      209591      1   53995  1013.0  11843.111667  11904.350000
# 209591      209592      1  111388  1732.0  12488.228333  12574.370000
# 209592      209593      1  121263  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# ...

# %%
#Again checking null values
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=df.rename(columns={'Unnamed: 0': 'Sr no' })
df
# Out:
#          Sr no  label  msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0            1      0   40191   272.0   3055.050000   3065.150000    220.13
# 1            2      1  142291   712.0  12122.000000  12124.750000   3691.26
# 2            3      1   33594   535.0   1398.000000   1398.000000    900.13
# 3            4      1  104157   241.0     21.228000     21.228000    159.42
# 4            5      1    6910   947.0    150.619333    150.619333   1098.90
# ...        ...    ...     ...     ...           ...           ...       ...
# 209588  209589      1   42866   404.0    151.872333    151.872333   1089.19
# 209589  209590      1  178248  1075.0     36.936000     36.936000   1728.36
# 209590  209591      1   53995  1013.0  11843.111667  11904.350000   5861.83
# 209591  209592      1  111388  1732.0  12488.228333  12574.370000    411.83
# 209592  209593      1  121263  1581.0   4489.362000   4534.820000    483.92
#
# ...

# %% [markdown]
# # Univariate ananlysis

# %%
sns.countplot(x='label',data=df)
print(df['label'].value_counts())
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
sns.histplot(x='msisdn',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='msisdn', ylabel='Count'>

# %%
sns.histplot(x='aon',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='aon', ylabel='Count'>

# %%
sns.histplot(x='daily_decr30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='Count'>

# %%
sns.histplot(x='daily_decr90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='daily_decr90', ylabel='Count'>

# %%
sns.histplot(x='rental30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='rental30', ylabel='Count'>

# %%
sns.histplot(x='rental90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='rental90', ylabel='Count'>

# %%
sns.histplot(x='last_rech_date_ma',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma', ylabel='Count'>

# %%
sns.histplot(x='last_rech_date_da',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='last_rech_date_da', ylabel='Count'>

# %%
sns.histplot(x='last_rech_amt_ma',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='last_rech_amt_ma', ylabel='Count'>

# %%
sns.histplot(x='cnt_ma_rech30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='Count'>

# %%
sns.histplot(x='fr_ma_rech30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='fr_ma_rech30', ylabel='Count'>

# %%
sns.histplot(x='sumamnt_ma_rech30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech30', ylabel='Count'>

# %%
sns.histplot(x='medianamnt_ma_rech30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech30', ylabel='Count'>

# %%
sns.histplot(x='medianmarechprebal30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='medianmarechprebal30', ylabel='Count'>

# %%
sns.histplot(x='cnt_ma_rech90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech90', ylabel='Count'>

# %%
sns.histplot(x='fr_ma_rech90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='fr_ma_rech90', ylabel='Count'>

# %%
sns.histplot(x='sumamnt_ma_rech90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech90', ylabel='Count'>

# %%
sns.histplot(x='medianamnt_ma_rech90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech90', ylabel='Count'>

# %%
sns.histplot(x='medianmarechprebal90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='medianmarechprebal90', ylabel='Count'>

# %%
sns.histplot(x='cnt_da_rech30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='cnt_da_rech30', ylabel='Count'>

# %%
sns.histplot(x='fr_da_rech30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='fr_da_rech30', ylabel='Count'>

# %%
sns.histplot(x='cnt_da_rech90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='cnt_da_rech90', ylabel='Count'>

# %%
sns.histplot(x='fr_da_rech90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='fr_da_rech90', ylabel='Count'>

# %%
sns.histplot(x='cnt_loans30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='cnt_loans30', ylabel='Count'>

# %%
sns.histplot(x='amnt_loans30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='Count'>

# %%
sns.histplot(x='maxamnt_loans30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30', ylabel='Count'>

# %%
sns.histplot(x='medianamnt_loans30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='medianamnt_loans30', ylabel='Count'>

# %%
sns.histplot(x='cnt_loans90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='cnt_loans90', ylabel='Count'>

# %%
sns.histplot(x='amnt_loans90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='amnt_loans90', ylabel='Count'>

# %%
sns.histplot(x='maxamnt_loans90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90', ylabel='Count'>

# %%
sns.histplot(x='medianamnt_loans90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='medianamnt_loans90', ylabel='Count'>

# %%
sns.histplot(x='payback30',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='payback30', ylabel='Count'>

# %%
sns.histplot(x='payback90',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='payback90', ylabel='Count'>

# %%
sns.countplot(x='pcircle',data=df)
print(df['pcircle'].value_counts())
# Out:
# 0    209593
# Name: pcircle, dtype: int64

# %%
sns.histplot(x='pdate',data=df,bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='pdate', ylabel='Count'>

# %%
#Let's drop some columns
df.drop('pcircle',inplace=True,axis=1)

# %%
df
# Out:
#          Sr no  label  msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0            1      0   40191   272.0   3055.050000   3065.150000    220.13
# 1            2      1  142291   712.0  12122.000000  12124.750000   3691.26
# 2            3      1   33594   535.0   1398.000000   1398.000000    900.13
# 3            4      1  104157   241.0     21.228000     21.228000    159.42
# 4            5      1    6910   947.0    150.619333    150.619333   1098.90
# ...        ...    ...     ...     ...           ...           ...       ...
# 209588  209589      1   42866   404.0    151.872333    151.872333   1089.19
# 209589  209590      1  178248  1075.0     36.936000     36.936000   1728.36
# 209590  209591      1   53995  1013.0  11843.111667  11904.350000   5861.83
# 209591  209592      1  111388  1732.0  12488.228333  12574.370000    411.83
# 209592  209593      1  121263  1581.0   4489.362000   4534.820000    483.92
#
# ...

# %% [markdown]
# # Describing Datasets

# %%
df.describe()
# Out:
#                Sr no          label         msisdn            aon  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177   93100.650179    8112.343445
# std     60504.431823       0.330519   53758.461427   75696.082531
# min         1.000000       0.000000       0.000000     -48.000000
# 25%     52399.000000       1.000000   46506.000000     246.000000
# 50%    104797.000000       1.000000   93073.000000     527.000000
# 75%    157195.000000       1.000000  139626.000000     982.000000
# max    209593.000000       1.000000  186242.000000  999860.755168
#
#         daily_decr30   daily_decr90       rental30       rental90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean     5381.402289    6082.515068    2692.581910    3483.406534
# std      9220.623400   10918.812767    4308.586781    5770.461279
# min       -93.012667     -93.012667  -23737.140000  -24720.580000
# ...

# %%
#Heatmap
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidth=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                          Sr no     label    msisdn       aon  daily_decr30  \
# Sr no                 1.000000  0.000403  0.000121 -0.002048      0.002739
# label                 0.000403  1.000000  0.001976 -0.003785      0.168298
# msisdn                0.000121  0.001976  1.000000  0.000566      0.000717
# aon                  -0.002048 -0.003785  0.000566  1.000000      0.001104
# daily_decr30          0.002739  0.168298  0.000717  0.001104      1.000000
# daily_decr90          0.003077  0.166150  0.000950  0.000374      0.977704
# rental30             -0.003906  0.058085 -0.001404 -0.000960      0.442066
# rental90             -0.003459  0.075521 -0.000691 -0.000790      0.458977
# last_rech_date_ma    -0.001853  0.003728 -0.000928  0.001692      0.000487
# last_rech_date_da    -0.001133  0.001711  0.001400 -0.001693     -0.001636
# last_rech_amt_ma     -0.001064  0.131804 -0.002368  0.004256      0.275837
# ...

# %%
#checking correlation
plt.figure(figsize=(22,7))
sns.heatmap(df.iloc[:,:20].corr(),annot=True,linewidth=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.iloc[:,20:37].corr(),annot=True,linewidth=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outliers Checking

# %%
df.skew()
# Out:
# Sr no                    0.000000
# label                   -2.270254
# msisdn                   0.000719
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# ...

# %% [markdown]
# Taking -/+ 0.5 as threshold
#
# except Sr no,msisdn and pdate all other columns has skewness present in it.

# %%
df['label'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['aon'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['daily_decr30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['daily_decr90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['rental30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['rental90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['last_rech_date_ma'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['last_rech_date_da'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['last_rech_amt_ma'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['cnt_ma_rech30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['fr_ma_rech30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['sumamnt_ma_rech30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['medianamnt_ma_rech30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['medianmarechprebal30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['cnt_ma_rech90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['fr_ma_rech90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['sumamnt_ma_rech90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['medianamnt_ma_rech90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['medianmarechprebal90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['cnt_da_rech30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['fr_da_rech30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['cnt_da_rech90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['fr_da_rech90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['cnt_loans30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['amnt_loans30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['medianamnt_loans30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['maxamnt_loans30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['cnt_loans90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['amnt_loans90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['maxamnt_loans90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['medianamnt_loans90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['payback30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['payback90'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing outliersRemoving outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64),
#  array([17, 17, 34, ..., 30, 28, 32], dtype=int64))

# %%
df=df[(z<3).all(axis=1)]
df
# Out:
#          Sr no  label  msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0            1      0   40191   272.0   3055.050000   3065.150000    220.13
# 1            2      1  142291   712.0  12122.000000  12124.750000   3691.26
# 2            3      1   33594   535.0   1398.000000   1398.000000    900.13
# 3            4      1  104157   241.0     21.228000     21.228000    159.42
# 4            5      1    6910   947.0    150.619333    150.619333   1098.90
# ...        ...    ...     ...     ...           ...           ...       ...
# 209588  209589      1   42866   404.0    151.872333    151.872333   1089.19
# 209589  209590      1  178248  1075.0     36.936000     36.936000   1728.36
# 209590  209591      1   53995  1013.0  11843.111667  11904.350000   5861.83
# 209591  209592      1  111388  1732.0  12488.228333  12574.370000    411.83
# 209592  209593      1  121263  1581.0   4489.362000   4534.820000    483.92
#
# ...

# %%
Data_Loss=((209593-161465)/209593)*100
Data_Loss
# Out:
# 22.962598941758554

# %% [markdown]
# # Separating data in x and y

# %%
x=df.drop('label',axis=1)
y=df['label']

# %% [markdown]
# # Transfroming dataset

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-2.19592207, -0.92667457, -0.71262182, ...,  1.84576489,
#          1.8829845 ,  0.69542977],
#        [-2.19556918,  0.90405418,  0.26254838, ..., -0.91291291,
#         -0.98791151,  1.440778  ],
#        [-2.19524988, -1.07763391, -0.09581692, ..., -0.91291291,
#         -0.98791151,  1.73327252],
#        ...,
#        [ 1.55247883, -0.63238411,  0.81169191, ...,  1.01680343,
#          0.81047152,  1.02733644],
#        [ 1.55249147,  0.41168392,  1.94362516, ..., -0.91291291,
#          1.415384  ,  0.88243291],
#        [ 1.55250411,  0.57293321,  1.72102218, ..., -0.91291291,
#         -0.98791151,  0.17157667]])

# %% [markdown]
# # Scaling Dataset

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x=sc.fit_transform(x)
x
# Out:
# array([[-2.19592207, -0.92667457, -0.71262182, ...,  1.84576489,
#          1.8829845 ,  0.69542977],
#        [-2.19556918,  0.90405418,  0.26254838, ..., -0.91291291,
#         -0.98791151,  1.440778  ],
#        [-2.19524988, -1.07763391, -0.09581692, ..., -0.91291291,
#         -0.98791151,  1.73327252],
#        ...,
#        [ 1.55247883, -0.63238411,  0.81169191, ...,  1.01680343,
#          0.81047152,  1.02733644],
#        [ 1.55249147,  0.41168392,  1.94362516, ..., -0.91291291,
#          1.415384  ,  0.88243291],
#        [ 1.55250411,  0.57293321,  1.72102218, ..., -0.91291291,
#         -0.98791151,  0.17157667]])

# %% [markdown]
# # Model Selection

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.svm import SVC
svc=SVC(kernel='rbf')
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
from sklearn.naive_bayes import MultinomialNB
mnb=MultinomialNB()
from sklearn.neighbors import KNeighborsClassifier
knc=KNeighborsClassifier()
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state ",i,"The Model perform very well")
        print("At random state :-",i)
        print("Training accuracy_score is :-",accuracy_score(y_train,pred_train)*100)
        print("Testing accuracy_score is :-",accuracy_score(y_test,pred_test)*100)
# Out:
# At random state  4 The Model perform very well
# At random state :- 4
# Training accuracy_score is :- 87.5979314402502
# Testing accuracy_score is :- 87.57315826959403
# At random state  7 The Model perform very well
# At random state :- 7
# Training accuracy_score is :- 87.59096398600316
# Testing accuracy_score is :- 87.59483479391818
# At random state  9 The Model perform very well
# At random state :- 9
# Training accuracy_score is :- 87.57625491592606
# Testing accuracy_score is :- 87.5545783916019
# At random state  12 The Model perform very well
# At random state :- 12
# Training accuracy_score is :- 87.58864150125414
# Testing accuracy_score is :- 87.64128448889852
# At random state  15 The Model perform very well
# At random state :- 15
# Training accuracy_score is :- 87.5816740470071
# Testing accuracy_score is :- 87.57625491592606
# At random state  19 The Model perform very well
# At random state :- 19
# Training accuracy_score is :- 87.58012572384108
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.25      0.36      4559
#            1       0.89      0.98      0.93     27734
#
#     accuracy                           0.88     32293
#    macro avg       0.77      0.61      0.64     32293
# weighted avg       0.85      0.88      0.85     32293

# %% [markdown]
# # Cross Validation of Dataset

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore=cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv :- ",j)
    print("Cross validation score is :-",lsc*100)
    print("accuracy_score is :-",lss*100)
    print("\n")
# Out:
# At cv :-  2
# Cross validation score is :- 87.55086347033999
# accuracy_score is :- 87.53599851360975
#
#
# At cv :-  3
# Cross validation score is :- 87.57563623010599
# accuracy_score is :- 87.53599851360975
#
#
# At cv :-  4
# Cross validation score is :- 87.5743978357437
# accuracy_score is :- 87.53599851360975
#
#
# At cv :-  5
# Cross validation score is :- 87.58740284272133
# accuracy_score is :- 87.53599851360975
#
#
# At cv :-  6
# Cross validation score is :- 87.59050069494481
# accuracy_score is :- 87.53599851360975
#
#
# At cv :-  7
# Cross validation score is :- 87.58244957604214
# accuracy_score is :- 87.53599851360975
#
#
# At cv :-  8
# Cross validation score is :- 87.59483608700171
# accuracy_score is :- 87.53599851360975
#
#
# At cv :-  9
# Cross validation score is :- 87.60350736185781
# accuracy_score is :- 87.53599851360975

# %%
lsscore_selected=cross_val_score(lr,x,y,cv=2).mean()
print("The cv score is: ",lsscore_selected,"\n The accuracy_score is: ",lss)
# Out:
# The cv score is:  0.8755086347033999
#  The accuracy_score is:  0.8753599851360976

# %% [markdown]
# # AUC-ROC Curve

# %%
from sklearn.metrics import roc_curve,auc
fpr,tpr,thresholds=roc_curve(pred_test,y_test)
roc_auc=auc(fpr,tpr)

plt.figure()
plt.plot(fpr,tpr,color='darkorange',lw=10,label='Roc curve (area=%0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color='navy',lw=10,linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Label')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Model Saving

# %%
import pickle
filename='Microcredit.dflt'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# # Conclusion

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com=pd.DataFrame({'original':a,'predicted':predicted},index=range(len(a)))
df_com
# Out:
#        original  predicted
# 0             1          1
# 1             1          1
# 2             1          1
# 3             1          1
# 4             1          1
# ...         ...        ...
# 32288         1          0
# 32289         1          1
# 32290         1          1
# 32291         1          1
# 32292         1          1
#
# [32293 rows x 2 columns]
