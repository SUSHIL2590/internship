# %% [markdown]
# # WEB SCRAPING – ASSIGNMENT 4

# %% [markdown]
# You have to handle commonly occurring EXCEPTIONS by using exception handling programing. To get
# information about selenium Exceptions. You may visit following links:
# 1. https://selenium-python.readthedocs.io/api.html
# 2. https://www.guru99.com/exception-handling-selenium.html
# 3. https://stackoverflow.com/questions/38022658/selenium-python-handling-no-such-elementexception/38023345

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains      

#Importing requests
import requests

# importing regex
import re


#importing warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %% [raw]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)
time.sleep(3)

# %%
rank = []
name = []
artist = []
up_date = []
views = []                                                           #declaring lists

top_vid = driver.find_element_by_xpath('//li[@class="toclevel-1 tocsection-2"]//a')
top_vid.click()
time.sleep(1)

for i in range (1, 31):                                              #using for loop to loop over all the rows at once
    xp = '//table[@class="wikitable sortable jquery-tablesorter"][1]//tbody//tr['
    rank_path = driver.find_element_by_xpath(xp + str(i) + ']//td[1]')
    name_path = driver.find_element_by_xpath(xp + str(i) + ']//td[2]')
    artist_path = driver.find_element_by_xpath(xp + str(i) + ']//td[3]')
    up_date_path = driver.find_element_by_xpath(xp + str(i) + ']//td[4]')
    views_path = driver.find_element_by_xpath(xp + str(i) + ']//td[5]')
    
    rank.append(rank_path.text)
    name.append(name_path.text)
    artist.append(artist_path.text)
    up_date.append(up_date_path.text)
    views.append(views_path.text)
    
wiki = pd.DataFrame({})                                             #creating dataframe
wiki['Rank'] = rank
wiki['Name'] = name
wiki['Artist'] = artist
wiki['Upload Date'] = up_date
wiki['Views'] = views
wiki.set_index('Rank', inplace = True)
wiki
# Out:
#                                                  Name  \
# Rank
# 1.                              "Baby Shark Dance"[3]
# 2.                                     "Despacito"[6]
# 3.                         "Johny Johny Yes Papa"[12]
# 4.                                 "Shape of You"[13]
# 5.                                "See You Again"[15]
# 6.                                    "Bath Song"[20]
# 7.                  "Phonics Song with Two Words"[21]
# 8.    "Learning Colors – Colorful Eggs on a Farm"[22]
# 9.                                  "Uptown Funk"[23]
# 10.    "Masha and the Bear – Recipe for Disaster"[24]
# 11.                               "Gangnam Style"[25]
# 12.                           "Wheels on the Bus"[30]
# 13.                              "Dame Tu Cosita"[31]
# 14.                                       "Sugar"[32]
# 15.                                        "Roar"[33]
# 16.                              "Counting Stars"[34]
# ...

# %% [raw]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
url = 'https://www.bcci.tv/'
driver.get(url)

# %%
intnat = driver.find_element_by_xpath('/html/body/nav/div/div[2]/ul[1]/li[2]/a')
try:
    intnat.click()
except ElementNotInteractableException:
    driver.get(intnat.get_attribute('href'))

# %%
fix = driver.find_element_by_xpath('/html/body/div[3]/div[1]/div/ul/li[1]/a')
fix.click()

# %%
match=[]
series=[]
place=[]
date=[]
time=[]
for i in url:
    driver.get(i)
    try:
        match_title=driver.find_element_by_xpath("//span[@class='matchOrderText ng-binding ng-scope']")
        match.append(match_title.text)
    except NoSuchElementException:
        match.append('No details available')
        
    try:
        series_title=driver.find_element_by_xpath("//h5[@class='ng-binding']/span")
        series.append(series_title.text)
    except NoSuchElementException:
        series.append("No details Available")
        
    try:
        place_title=driver.find_element_by_xpath("//span[@class='ng-binding ng-scope']")
        place.append(place_title.text.split()[-1])
    except NoSuchElementException:
        place.append("No details Available")
        
    try:
        date_title=driver.find_element_by_xpath("//div[@class='match-card-left match-schedule']")
        date.append(date_title.text)
    except NoSuchElementException:
        date.append("No details Available")     
        
    try:
        time_title=driver.find_element_by_xpath("//div[@class='match-card-right match-schedule']")
        time.append(time_title.text)
    except NoSuchElementException:
        time.append("No details Available")
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# <ipython-input-14-2b4287601c94> in <module>
#       5 time=[]
#       6 for i in url:
# ----> 7     driver.get(i)
#       8     try:
#       9         match_title=driver.find_element_by_xpath("//span[@class='matchOrderText ng-binding ng-scope']")
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     435         Loads a web page in the current browser session.
#     436         """
# --> 437         self.execute(Command.GET, {'url': url})
#     438
#     439     @property
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
# ...

# %%
df=pd.DataFrame({"Match":match,
                "Series":series,
                "Place":place,
                "Date":date,
                "Time":time})
print(df)
# Out:
# Empty DataFrame
# Columns: [Match, Series, Place, Date, Time]
# Index: []

# %% [raw]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
url = 'https://www.guru99.com/'
driver.get(url)

# %%
sel = driver.find_element_by_xpath('//li//a[@title="Selenium"]')
sel.click()

# %%
exc_hand = driver.find_element_by_xpath('//a[@title="Selenium Exception Handling (Common Exceptions List)"]')
exc_hand.click()

# %%
name = []
desc = []                                                  #declaring lists

for i in range (2, 43):                                    #using for loop to loop over all the rows at once
    xp = '//table[@class="table table-striped"]//tr['
    name_tag = driver.find_element_by_xpath(xp + str(i) + ']//td[1]')
    desc_tag = driver.find_element_by_xpath(xp + str(i) + ']//td[2]')
    
    name.append(name_tag.text)
    desc.append(desc_tag.text)
    
ex = pd.DataFrame({})                                   #creating dataframe
ex['Name'] = name
ex['Description'] = desc
ex
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [raw]
# 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
url = 'https://www.billboard.com/'
driver.get(url)

# %%
charts=driver.find_element_by_xpath("/html/body/div[3]/div[6]/div/div/div/ul/li[1]/h3/a")
try:
    charts.click()
except ElementNotInteractableException:
    driver.get(charts.get_attribute('href'))

# %%
hot = driver.find_element_by_xpath('/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a')
hot.click()

# %%
title = []
artist = []
lst_wk = []
peak = []
wk_ch = []                                             #declaring lists



try:
    title_path = driver.find_elements_by_xpath('//id[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet"]//h3')
    for i in title_path: 
        title.append(i.text)
    except NoSuchElementException:
        title.append('No details available')
 

try:
    artist_path = driver.find_elements_by_xpath('//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet"]')
    for i in artist_path:
        artist.append(i.text)
    except NoSuchElementException:
        artist.append('No details available')
    
 
lst_wk_path = driver.find_elements_by_xpath('//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max lrv-u-flex-grow-1"]')
try:
    for i in lst_wk_path:
        lst_wk.append(i.text)
    except NoSuchElementException:
        lst_wk.append('No details available')
    
 
peak_path = driver.find_elements_by_xpath('//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light lrv-u-flex-grow-1"]')
try:
    for i in peak_path:        
        peak.append(i.text)
    except NoSuchElementException:
        peak_path.append('No details available')
    
    
wk_ch_path = driver.find_elements_by_xpath('//span[@class="c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet"]')
try:
    for i in wk_ch_path:   
        wk_ch.append(i.text)
    except NoSuchElementException:
        wk_ch_path.append('No details available')
    
    
billboard = pd.DataFrame({})                                   #creating dataframe
billboard['Song'] = title
billboard['Artist'] = artist
billboard['Last Week'] = lst_wk
billboard['Peak'] = peak
billboard['Weeks on Chart'] = wk_ch
billboard
# Out:
#   File "<ipython-input-48-5627e37b93e1>", line 13
#     except NoSuchElementException:
#     ^
# SyntaxError: invalid syntax

# %% [raw]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
book = []
author = []
vol = []
pub = []
genre = []                                     #declaring lists

url8 = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/'
driver.get(url8)
time.sleep(3)                               #accessing the url

# %%
for i in range (0,100):                                   #using for loop to loop over all the rows at once
    book_tag = driver.find_element_by_id('table-cell-10943-' + str(i) + '-1')
    auth_tag = driver.find_element_by_id('table-cell-10943-' + str(i) + '-2')
    vol_tag = driver.find_element_by_id('table-cell-10943-' + str(i) + '-3')
    pub_tag = driver.find_element_by_id('table-cell-10943-' + str(i) + '-4')
    gen_tag = driver.find_element_by_id('table-cell-10943-' + str(i) + '-5')
    
    book.append(book_tag.text)
    author.append(auth_tag.text)
    vol.append(vol_tag.text)
    pub.append(pub_tag.text)
    genre.append(gen_tag.text)
    
novels = pd.DataFrame({})                            #creating dataframe
novels['Title'] = book
novels['Author'] = author
novels['Volumes Sold'] = vol
novels['Publisher'] = pub
novels['Genre'] = genre
novels
# Out:
#                                                 Title            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# ...

# %% [raw]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
url = 'https://www.imdb.com/list/ls095964455/'
driver.get(url)
time.sleep(3)

# %%
name = []
year = []
genre = []
run = []
ratings = []
votes = []                                          #declaring lists

name_tag = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]//a')
year_tag = driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"]')
genre_tag = driver.find_elements_by_xpath('//span[@class="genre"]')
run_tag = driver.find_elements_by_xpath('//span[@class="runtime"]')
ratings_tag = driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]//span[2]')
votes_tag = driver.find_elements_by_xpath('//span[@name="nv"]')

for i in name_tag:                                             #looping over tag and adding relevant text to the list
    name.append(i.text)
    
for i in year_tag:                                              #looping over tag and adding relevant text to the list
    year.append(i.text)
    
for i in genre_tag:                                         #looping over tag and adding relevant text to the list
    genre.append(i.text)
    
for i in run_tag:                                              #looping over tag and adding relevant text to the list
    run.append(i.text)
    
for i in ratings_tag:                                         #looping over tag and adding relevant text to the list
    ratings.append(i.text)
    
for i in votes_tag:                                          #looping over tag and adding relevant text to the list
    votes.append(i.text)
    
imdb = pd.DataFrame({})                                              #creating dataframe
imdb['Name'] = name
imdb['Year Span'] = year
imdb['Genre'] = genre
imdb['Run time'] = run
imdb['Ratings'] = ratings
imdb['Votes'] = votes

imdb
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  1,981,153
# ...

# %% [raw]
# 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
url = 'https://archive.ics.uci.edu/'                 
driver.get(url)
time.sleep(3)

# %%
ds = driver.find_element_by_xpath('//font[@size="3"]')
ds.click()
time.sleep(2)

# %%
ds_name = []
dtype = []
task = []
att = []
no_inst = []
no_att = []
year = []                                                #declaring lists

total_tag = driver.find_element_by_xpath('//table[@width="100%"]//p[@class="big"]//b')
total = int (total_tag.text) + 2

for i in range (2, total):          #creating a list of list in which each element will contain all the column info in a list
    
    data_tag = driver.find_elements_by_xpath('//table[@border="1"]//tr[' + str(i) + ']//p')
    ds_name.append(data_tag[0].text)
    dtype.append(data_tag[1].text)
    task.append(data_tag[2].text)
    att.append(data_tag[3].text)
    no_inst.append(data_tag[4].text)
    no_att.append(data_tag[5].text)
    year.append(data_tag[6].text)
    
uci = pd.DataFrame({})                                             #creating dataframe
uci['Dataset name'] = ds_name
uci['Data type'] = dtype
uci['Task'] = task
uci['Attribute type'] = att
uci['No of instances'] = no_inst
uci['No of attribute'] = no_att
uci['Year'] = year

uci
# Out:
#                                           Dataset name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
